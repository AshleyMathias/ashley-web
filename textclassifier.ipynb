# %% [markdown]
# <a href="https://colab.research.google.com/github/AshleyMathias/ashley-web/blob/main/textclassifier.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !wget -nc https://raw.githubusercontent.com/lazyprogrammer/machine_learning_examples/master/hmm_class/edgar_allan_poe.txt
# !wget -nc https://raw.githubusercontent.com/lazyprogrammer/machine_learning_examples/master/hmm_class/robert_frost.txt
# Out:
# --2024-07-17 16:07:13--  https://raw.githubusercontent.com/lazyprogrammer/machine_learning_examples/master/hmm_class/edgar_allan_poe.txt
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.108.133, 185.199.109.133, 185.199.110.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.108.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 26622 (26K) [text/plain]
# Saving to: ‘edgar_allan_poe.txt’
#
# edgar_allan_poe.txt 100%[===================>]  26.00K  --.-KB/s    in 0.003s
#
# 2024-07-17 16:07:13 (10.1 MB/s) - ‘edgar_allan_poe.txt’ saved [26622/26622]
#
# --2024-07-17 16:07:14--  https://raw.githubusercontent.com/lazyprogrammer/machine_learning_examples/master/hmm_class/robert_frost.txt
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.108.133, 185.199.109.133, 185.199.110.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.108.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 56286 (55K) [text/plain]
# Saving to: ‘robert_frost.txt’
#
# robert_frost.txt    100%[===================>]  54.97K  --.-KB/s    in 0.02s
#
# 2024-07-17 16:07:14 (3.25 MB/s) - ‘robert_frost.txt’ saved [56286/56286]

# %%
import numpy as np
import matplotlib.pyplot as plt
import string
from sklearn.model_selection import train_test_split

# %%
input_files=[
    'edgar_allan_poe.txt',
    'robert_frost.txt',
]

# %%
# !head edgar_allan_poe.txt
# Out:
# LO! Death hath rear'd himself a throne
# In a strange city, all alone,
# Far down within the dim west
# Where the good, and the bad, and the worst, and the best,
# Have gone to their eternal rest.
#
# There shrines, and palaces, and towers
# Are not like any thing of ours
# Oh no! O no! ours never loom
# To heaven with that ungodly gloom!

# %%
# !head robert_frost.txt
# Out:
# Two roads diverged in a yellow wood,
# And sorry I could not travel both
# And be one traveler, long I stood
# And looked down one as far as I could
# To where it bent in the undergrowth;
#
# Then took the other, as just as fair,
# And having perhaps the better claim
# Because it was grassy and wanted wear,
# Though as for that the passing there

# %%
#collect robert_frost.txt
input_texts=[]
labels=[]
for label, f in enumerate(input_files):
  print(f"{f} corresponds to label {label}")

  for line in open(f):
    line = line.rstrip().lower()
    if line:
      # remove punctuation
      line = line.translate(str.maketrans('', '', string.punctuation))

      input_texts.append(line)
      labels.append(label)
# Out:
# edgar_allan_poe.txt corresponds to label 0
# robert_frost.txt corresponds to label 1

# %%
train_text, test_text, Ytrain, Ytest = train_test_split(input_texts, labels)

# %%
len(Ytrain), len(Ytest)
# Out:
# (1615, 539)

# %%
train_text[:5]
# Out:
# ['then ran and shouted shut the bedroom door',
#  'a governor it was proclaimed this time',
#  'in the misty mid region of weir',
#  'ah night of all nights in the year',
#  'by having me a witch or something happened']

# %%
idx = 1
word2idx = {'<unk>': 0}

# %%
# populate word2idx
for text in train_text:
    tokens = text.split()
    for token in tokens:
      if token not in word2idx:
        word2idx[token] = idx
        idx += 1

# %%
word2idx
# Out:
# {'<unk>': 0,
#  'then': 1,
#  'ran': 2,
#  'and': 3,
#  'shouted': 4,
#  'shut': 5,
#  'the': 6,
#  'bedroom': 7,
#  'door': 8,
#  'a': 9,
#  'governor': 10,
#  'it': 11,
#  'was': 12,
#  'proclaimed': 13,
#  'this': 14,
#  'time': 15,
#  'in': 16,
#  'misty': 17,
#  'mid': 18,
#  'region': 19,
#  'of': 20,
#  'weir': 21,
#  'ah': 22,
#  'night': 23,
#  'all': 24,
#  'nights': 25,
#  'year': 26,
#  'by': 27,
#  'having': 28,
#  'me': 29,
#  'witch': 30,
#  'or': 31,
#  'something': 32,
#  'happened': 33,
#  'to': 34,
#  'break': 35,
#  'him': 36,
#  'you': 37,
#  'may': 38,
#  'have': 39,
#  'job': 40,
#  'but': 41,
#  'being': 42,
#  'mounted': 43,
#  'bareback': 44,
#  'on': 45,
#  'earth': 46,
#  'ill': 47,
#  'show': 48,
#  'how': 49,
#  'she': 50,
#  'had': 51,
#  'her': 52,
#  'sills': 53,
#  'extended': 54,
#  'so': 55,
#  'halfway': 56,
#  'down': 57,
#  'he': 58,
#  'fought': 59,
#  'battle': 60,
#  'i': 61,
#  'struck': 62,
#  'hand': 63,
#  'off': 64,
#  'brittle': 65,
#  'floor': 66,
#  'lord': 67,
#  'if': 68,
#  'were': 69,
#  'dream': 70,
#  'everyone': 71,
#  'yes': 72,
#  'do': 73,
#  'fairylike': 74,
#  'melody': 75,
#  'there': 76,
#  'floats': 77,
#  'skyhigh': 78,
#  'with': 79,
#  'both': 80,
#  'hands': 81,
#  'can': 82,
#  'see': 83,
#  'now': 84,
#  'psyche': 85,
#  'uplifting': 86,
#  'finger': 87,
#  'weep': 88,
#  'for': 89,
#  'what': 90,
#  'little': 91,
#  'things': 92,
#  'could': 93,
#  'make': 94,
#  'them': 95,
#  'glad': 96,
#  'hast': 97,
#  'thou': 98,
#  'not': 99,
#  'dragged': 100,
#  'diana': 101,
#  'from': 102,
#  'car': 103,
#  'everything': 104,
#  'gave': 105,
#  'up': 106,
#  'shall': 107,
#  'dawn': 108,
#  'upon': 109,
#  'desolate': 110,
#  'appear': 111,
#  'like': 112,
#  'standing': 113,
#  'dont': 114,
#  'be': 115,
#  'too': 116,
#  'technical': 117,
#  'three': 118,
#  'cards': 119,
#  'as': 120,
#  'winds': 121,
#  'might': 122,
#  'rouse': 123,
#  'leaves': 124,
#  'no': 125,
#  'step': 126,
#  'trodden': 127,
#  'black': 128,
#  'shes': 129,
#  'earnest': 130,
#  'appears': 131,
#  'someone': 132,
#  'came': 133,
#  'cart': 134,
#  'pair': 135,
#  'stopped': 136,
#  'tomb': 137,
#  'is': 138,
#  'good': 139,
#  'home': 140,
#  'ask': 141,
#  'better': 142,
#  'distinct': 143,
#  'its': 144,
#  'duplicate': 145,
#  'horn': 146,
#  'headboard': 147,
#  'where': 148,
#  'wants': 149,
#  'get': 150,
#  'out': 151,
#  'plowed': 152,
#  'ground': 153,
#  'cold': 154,
#  'digger': 155,
#  'light': 156,
#  'lurid': 157,
#  'sea': 158,
#  'curl': 159,
#  'round': 160,
#  'bad': 161,
#  'married': 162,
#  'when': 163,
#  'chance': 164,
#  'lets': 165,
#  'go': 166,
#  'place': 167,
#  'hoed': 168,
#  'yesterday': 169,
#  'life': 170,
#  'long': 171,
#  'bed': 172,
#  'wrote': 173,
#  'well': 174,
#  'right': 175,
#  'here': 176,
#  'books': 177,
#  'they': 178,
#  'halted': 179,
#  'helpless': 180,
#  'landing': 181,
#  'think': 182,
#  'know': 183,
#  'country': 184,
#  'warren': 185,
#  'at': 186,
#  'march': 187,
#  'meeting': 188,
#  'reason': 189,
#  'travellers': 190,
#  'within': 191,
#  'that': 192,
#  'valley': 193,
#  'bade': 194,
#  'pause': 195,
#  'before': 196,
#  'gardengate': 197,
#  'ive': 198,
#  'tasted': 199,
#  'desire': 200,
#  'blushes': 201,
#  'love': 202,
#  'got': 203,
#  'one': 204,
#  'himself': 205,
#  'perhaps': 206,
#  'about': 207,
#  'henry': 208,
#  'hudsons': 209,
#  'gone': 210,
#  'present': 211,
#  'pathway': 212,
#  'part': 213,
#  'wampum': 214,
#  'call': 215,
#  'mind': 216,
#  'we': 217,
#  'complain': 218,
#  'old': 219,
#  'wall': 220,
#  'burns': 221,
#  'sunny': 222,
#  'cheek': 223,
#  'heaven': 224,
#  'gives': 225,
#  'glimpses': 226,
#  'only': 227,
#  'those': 228,
#  'whos': 229,
#  'button': 230,
#  'would': 231,
#  'self': 232,
#  'station': 233,
#  'vow': 234,
#  'must': 235,
#  'near': 236,
#  'some': 237,
#  'ocean': 238,
#  'throbbing': 239,
#  'far': 240,
#  'free': 241,
#  'four': 242,
#  'yours': 243,
#  'mine': 244,
#  'each': 245,
#  'branch': 246,
#  'two': 247,
#  'weeks': 248,
#  'since': 249,
#  'which': 250,
#  'seven': 251,
#  'my': 252,
#  'founts': 253,
#  'bliss': 254,
#  'drear': 255,
#  'path': 256,
#  'alas': 257,
#  'grows': 258,
#  'youthful': 259,
#  'forms': 260,
#  'faces': 261,
#  'while': 262,
#  'listen': 263,
#  'red': 264,
#  'levin': 265,
#  'thats': 266,
#  'why': 267,
#  'cant': 268,
#  'decently': 269,
#  'refuse': 270,
#  'ghoulhaunted': 271,
#  'woodland': 272,
#  'preyest': 273,
#  'thus': 274,
#  'poets': 275,
#  'heart': 276,
#  'someday': 277,
#  'will': 278,
#  'gailyjewelld': 279,
#  'dead': 280,
#  'said': 281,
#  'took': 282,
#  'his': 283,
#  'age': 284,
#  'rights': 285,
#  'are': 286,
#  'harder': 287,
#  'take': 288,
#  'always': 289,
#  'hers': 290,
#  'stole': 291,
#  'goblet': 292,
#  'childrens': 293,
#  'playhouse': 294,
#  'daylight': 295,
#  'beauty': 296,
#  'birth': 297,
#  'comes': 298,
#  'softly': 299,
#  'rattling': 300,
#  'verified': 301,
#  'name': 302,
#  'next': 303,
#  'morning': 304,
#  'toffile': 305,
#  'full': 306,
#  'end': 307,
#  'say': 308,
#  'hes': 309,
#  'much': 310,
#  'help': 311,
#  'tell': 312,
#  'ever': 313,
#  'cared': 314,
#  'hall': 315,
#  'finished': 316,
#  'tender': 317,
#  'verse': 318,
#  'escaped': 319,
#  'their': 320,
#  'outrage': 321,
#  'outwalked': 322,
#  'furthest': 323,
#  'city': 324,
#  'cellar': 325,
#  'windows': 326,
#  'banked': 327,
#  'sawdust': 328,
#  'death': 329,
#  'more': 330,
#  'happy': 331,
#  'clime': 332,
#  'gilt': 333,
#  'gold': 334,
#  'wouldnt': 335,
#  'wanted': 336,
#  'try': 337,
#  'noise': 338,
#  'shoulders': 339,
#  'dragging': 340,
#  'yellow': 341,
#  'strands': 342,
#  'flight': 343,
#  'kitchen': 344,
#  'waves': 345,
#  'redder': 346,
#  'glow': 347,
#  'just': 348,
#  'oer': 349,
#  'bright': 350,
#  'island': 351,
#  'smile': 352,
#  'speculation': 353,
#  'im': 354,
#  'going': 355,
#  'wont': 356,
#  'bird': 357,
#  'an': 358,
#  'angelic': 359,
#  'gift': 360,
#  'names': 361,
#  'joe': 362,
#  'vulture': 363,
#  'whose': 364,
#  'wings': 365,
#  'dull': 366,
#  'realities': 367,
#  'hillside': 368,
#  'day': 369,
#  'sun': 370,
#  'come': 371,
#  'across': 372,
#  'sacred': 373,
#  'sill': 374,
#  'should': 375,
#  'thee': 376,
#  'deem': 377,
#  'wise': 378,
#  'though': 379,
#  'strange': 380,
#  'muffled': 381,
#  'looks': 382,
#  'way': 383,
#  'give': 384,
#  'sleep': 385,
#  'hell': 386,
#  'sort': 387,
#  'swear': 388,
#  'away': 389,
#  'awful': 390,
#  'remember': 391,
#  'greatly': 392,
#  'afraid': 393,
#  'fire': 394,
#  'first': 395,
#  'impulse': 396,
#  'knob': 397,
#  'nature': 398,
#  'very': 399,
#  'hours': 400,
#  'breathing': 401,
#  'low': 402,
#  'resemble': 403,
#  'nothing': 404,
#  'ours': 405,
#  'withering': 406,
#  'sere': 407,
#  'uncommonly': 408,
#  'deep': 409,
#  'snow': 410,
#  'has': 411,
#  'made': 412,
#  'hope': 413,
#  'died': 414,
#  'idols': 415,
#  'diamond': 416,
#  'eye': 417,
#  'hold': 418,
#  'bones': 419,
#  'didnt': 420,
#  'smoke': 421,
#  'rolled': 422,
#  'inside': 423,
#  'sockets': 424,
#  'eyes': 425,
#  'magical': 426,
#  'sad': 427,
#  'sound': 428,
#  'wherever': 429,
#  'wet': 430,
#  'hurt': 431,
#  'hen': 432,
#  'ought': 433,
#  'us': 434,
#  'setting': 435,
#  'traps': 436,
#  'let': 437,
#  'myself': 438,
#  'means': 439,
#  'caves': 440,
#  'leaf': 441,
#  'lingered': 442,
#  'brown': 443,
#  'poor': 444,
#  'man': 445,
#  'been': 446,
#  'resurrection': 447,
#  'deepburied': 448,
#  'faith': 449,
#  'through': 450,
#  'mowing': 451,
#  'field': 452,
#  'highest': 453,
#  'noon': 454,
#  'simply': 455,
#  'lay': 456,
#  'goodlooking': 457,
#  'picked': 458,
#  'fresh': 459,
#  'window': 460,
#  'glass': 461,
#  'want': 462,
#  'hear': 463,
#  'talk': 464,
#  'grass': 465,
#  'o': 466,
#  'thrive': 467,
#  'pearl': 468,
#  'ruby': 469,
#  'glowing': 470,
#  'leave': 471,
#  'flowers': 472,
#  'am': 473,
#  'sure': 474,
#  'werent': 475,
#  'tremulous': 476,
#  'men': 477,
#  'mistake': 478,
#  'never': 479,
#  'saw': 480,
#  'house': 481,
#  'deserted': 482,
#  'pipe': 483,
#  'mouth': 484,
#  'jug': 485,
#  'mean': 486,
#  'else': 487,
#  'attic': 488,
#  'less': 489,
#  'than': 490,
#  'pale': 491,
#  'dim': 492,
#  'match': 493,
#  'flame': 494,
#  'getting': 495,
#  'size': 496,
#  'faster': 497,
#  'slower': 498,
#  'chanced': 499,
#  'built': 500,
#  'stone': 501,
#  'baptismal': 502,
#  'font': 503,
#  'outdoors': 504,
#  'meddle': 505,
#  'fate': 506,
#  'state': 507,
#  'glory': 508,
#  'befitting': 509,
#  'hath': 510,
#  'palsied': 511,
#  'many': 512,
#  'years': 513,
#  'lead': 514,
#  'aright': 515,
#  'oh': 516,
#  'hawks': 517,
#  'chickentime': 518,
#  'left': 519,
#  'furniture': 520,
#  'answering': 521,
#  'your': 522,
#  'knock': 523,
#  'theres': 524,
#  'wrong': 525,
#  'terror': 526,
#  'spoke': 527,
#  'letting': 528,
#  'sink': 529,
#  'trance': 530,
#  'withdrawing': 531,
#  'into': 532,
#  'rain': 533,
#  'brush': 534,
#  'crooked': 535,
#  'stroke': 536,
#  'shift': 537,
#  'shelter': 538,
#  'without': 539,
#  'sos': 540,
#  'lonesome': 541,
#  'october': 542,
#  'lying': 543,
#  'fell': 544,
#  'rejected': 545,
#  'bolder': 546,
#  'note': 547,
#  'swell': 548,
#  'lake': 549,
#  'auber': 550,
#  'arthur': 551,
#  'amy': 552,
#  'bulkhead': 553,
#  'doubledoors': 554,
#  'doublelocked': 555,
#  'however': 556,
#  'natural': 557,
#  'exclaimed': 558,
#  'who': 559,
#  'afar': 560,
#  'tis': 561,
#  'plain': 562,
#  'double': 563,
#  'care': 564,
#  'stardials': 565,
#  'hinted': 566,
#  'morn': 567,
#  'couldnt': 568,
#  'living': 569,
#  'aint': 570,
#  'seen': 571,
#  'tears': 572,
#  'dry': 573,
#  'stranger': 574,
#  'cousins': 575,
#  'family': 576,
#  'tree': 577,
#  'speak': 578,
#  'wasted': 579,
#  'entombed': 580,
#  'hour': 581,
#  'find': 582,
#  'anyone': 583,
#  'start': 584,
#  'lately': 585,
#  'slept': 586,
#  'apathy': 587,
#  'short': 588,
#  'sell': 589,
#  'johns': 590,
#  'safe': 591,
#  'stay': 592,
#  'legended': 593,
#  'folks': 594,
#  'given': 595,
#  'speaking': 596,
#  'even': 597,
#  'summer': 598,
#  'beneath': 599,
#  'tamarind': 600,
#  'fix': 601,
#  'safely': 602,
#  'trust': 603,
#  'gleaming': 604,
#  'other': 605,
#  'worlds': 606,
#  'spell': 607,
#  'pipes': 608,
#  'smoking': 609,
#  'unembodied': 610,
#  'essence': 611,
#  'tempt': 612,
#  'waters': 613,
#  'takes': 614,
#  'money': 615,
#  'theyre': 616,
#  'worth': 617,
#  'our': 618,
#  'memories': 619,
#  'treacherous': 620,
#  'winged': 621,
#  'odour': 622,
#  'went': 623,
#  'wantonest': 624,
#  'singing': 625,
#  'birds': 626,
#  'used': 627,
#  'sing': 628,
#  'along': 629,
#  'toteroad': 630,
#  'heavy': 631,
#  'iron': 632,
#  'bells': 633,
#  'sometime': 634,
#  'cased': 635,
#  'world': 636,
#  'rare': 637,
#  'radiant': 638,
#  'song': 639,
#  'uttered': 640,
#  'alone': 641,
#  'stand': 642,
#  'twenty': 643,
#  'cock': 644,
#  'twentyfive': 645,
#  'mother': 646,
#  'stark': 647,
#  'worship': 648,
#  'star': 649,
#  'west': 650,
#  'surer': 651,
#  'makes': 652,
#  'worse': 653,
#  'blind': 654,
#  'reconnoitre': 655,
#  'hens': 656,
#  'blowing': 657,
#  'stillgoing': 658,
#  'every': 659,
#  'joints': 660,
#  'sometimes': 661,
#  'wander': 662,
#  'beaten': 663,
#  'ways': 664,
#  'troop': 665,
#  'echoes': 666,
#  'sweet': 667,
#  'duty': 668,
#  'coming': 669,
#  'enough': 670,
#  'posies': 671,
#  'inner': 672,
#  'windowsill': 673,
#  'look': 674,
#  'raspberry': 675,
#  'vines': 676,
#  'die': 677,
#  'suddenly': 678,
#  'arisen': 679,
#  '2o3': 680,
#  'till': 681,
#  'caught': 682,
#  'wind': 683,
#  'opening': 684,
#  'covers': 685,
#  'agony': 686,
#  'sobbed': 687,
#  'disturbed': 688,
#  'slumbering': 689,
#  'village': 690,
#  'street': 691,
#  'truly': 692,
#  'young': 693,
#  'folk': 694,
#  'held': 695,
#  'dispose': 696,
#  'either': 697,
#  'fly': 698,
#  'flickers': 699,
#  'builder': 700,
#  'building': 701,
#  'god': 702,
#  'single': 703,
#  'bough': 704,
#  'groping': 705,
#  'after': 706,
#  'jam': 707,
#  'crisped': 708,
#  'acquainted': 709,
#  'wait': 710,
#  'until': 711,
#  'wonder': 712,
#  'sold': 713,
#  'farm': 714,
#  'neighbours': 715,
#  'bandmusic': 716,
#  'playing': 717,
#  'wrought': 718,
#  'trees': 719,
#  'breath': 720,
#  'storm': 721,
#  'moon': 722,
#  'confusion': 723,
#  'aglitter': 724,
#  'figures': 725,
#  'described': 726,
#  'ere': 727,
#  'any': 728,
#  'shine': 729,
#  'meridian': 730,
#  'glare': 731,
#  'converging': 732,
#  'slides': 733,
#  'avalanches': 734,
#  'board': 735,
#  'laid': 736,
#  'walk': 737,
#  'dryshod': 738,
#  'thrown': 739,
#  'open': 740,
#  'temples': 741,
#  'graves': 742,
#  'shoes': 743,
#  'primped': 744,
#  'dance': 745,
#  'melancholy': 746,
#  'shrine': 747,
#  'lips': 748,
#  'thy': 749,
#  'people': 750,
#  'keep': 751,
#  'grief': 752,
#  'joy': 753,
#  'hate': 754,
#  'child': 755,
#  'wasnt': 756,
#  'whom': 757,
#  'thine': 758,
#  'absence': 759,
#  'lean': 760,
#  'explain': 761,
#  'fever': 762,
#  'moonbeam': 763,
#  'hangs': 764,
#  'replied': 765,
#  'ulalume': 766,
#  'endless': 767,
#  'theme': 768,
#  'praise': 769,
#  'neck': 770,
#  'thought': 771,
#  'spare': 772,
#  'clothes': 773,
#  'garden': 774,
#  'presented': 775,
#  'land': 776,
#  'tide': 777,
#  'these': 778,
#  'cheeks': 779,
#  'worm': 780,
#  'dies': 781,
#  'faroff': 782,
#  'happier': 783,
#  'unfortunately': 784,
#  'kind': 785,
#  'becoming': 786,
#  'reconciled': 787,
#  'john': 788,
#  'touch': 789,
#  'knows': 790,
#  'friends': 791,
#  'chains': 792,
#  'hermon': 793,
#  'hill': 794,
#  'brought': 795,
#  'back': 796,
#  'thinks': 797,
#  'word': 798,
#  'hadnt': 799,
#  'gnawed': 800,
#  'hitching': 801,
#  'posts': 802,
#  'girl': 803,
#  'voices': 804,
#  'seem': 805,
#  'ye': 806,
#  'avengers': 807,
#  'libertys': 808,
#  'wrongs': 809,
#  'throw': 810,
#  'picture': 811,
#  'screen': 812,
#  'looked': 813,
#  'saddest': 814,
#  'lane': 815,
#  'live': 816,
#  'doorsill': 817,
#  'corner': 818,
#  'piece': 819,
#  'ralle': 820,
#  'sioux': 821,
#  'control': 822,
#  'once': 823,
#  'told': 824,
#  'heard': 825,
#  'throve': 826,
#  'headed': 827,
#  'for—': 828,
#  'dwelling': 829,
#  'hoary': 830,
#  'groans': 831,
#  'woe': 832,
#  'saturn': 833,
#  'mars': 834,
#  'riddle': 835,
#  'genealogy': 836,
#  'dark': 837,
#  'own': 838,
#  'property': 839,
#  'fall': 840,
#  'abouncing': 841,
#  'feet': 842,
#  'amid': 843,
#  'earthly': 844,
#  'moans': 845,
#  'italian': 846,
#  'tones': 847,
#  'murmured': 848,
#  'threw': 849,
#  'wide': 850,
#  'enter': 851,
#  'town': 852,
#  'settle': 853,
#  'hence': 854,
#  'doesnt': 855,
#  'marry': 856,
#  'lost': 857,
#  'brook': 858,
#  'raises': 859,
#  'empty': 860,
#  'half': 861,
#  'believe': 862,
#  'wild': 863,
#  'fraught': 864,
#  'sanctified': 865,
#  'elysian': 866,
#  'yourself': 867,
#  'knew': 868,
#  'month': 869,
#  'written': 870,
#  'sister': 871,
#  'such': 872,
#  'isnt': 873,
#  'mortgage': 874,
#  'does': 875,
#  'purport': 876,
#  'grandsirs': 877,
#  'likely': 878,
#  'regard': 879,
#  'over': 880,
#  'descended': 881,
#  'tended': 882,
#  'art': 883,
#  'son': 884,
#  'common': 885,
#  'table': 886,
#  'rear': 887,
#  'softmurmured': 888,
#  'words': 889,
#  'fulfilled': 890,
#  'looking': 891,
#  'finding': 892,
#  'youll': 893,
#  'expecting': 894,
#  'pity': 895,
#  'estelle': 896,
#  'great': 897,
#  'monolithic': 898,
#  'knees': 899,
#  'former': 900,
#  'point': 901,
#  'skies': 902,
#  'often': 903,
#  'passing': 904,
#  'times': 905,
#  'twas': 906,
#  'warrant': 907,
#  'sight': 908,
#  'awake': 909,
#  'soul': 910,
#  'quarry': 911,
#  'found': 912,
#  'fingerbone': 913,
#  'equally': 914,
#  'lightning': 915,
#  'scribble': 916,
#  'gnawing': 917,
#  'whined': 918,
#  'grave': 919,
#  'windbreak': 920,
#  'whirling': 921,
#  'frenzies': 922,
#  'natures': 923,
#  'green': 924,
#  'heed': 925,
#  'blushed': 926,
#  'bloomed': 927,
#  'around': 928,
#  'lifting': 929,
#  'forgot': 930,
#  'rolls': 931,
#  'ether': 932,
#  'sighs': 933,
#  'fullorbed': 934,
#  'soaring': 935,
#  'shudder': 936,
#  'notes': 937,
#  'assailed': 938,
#  'monarchs': 939,
#  'high': 940,
#  'estate': 941,
#  'hed': 942,
#  'admiring': 943,
#  'universal': 944,
#  'throne': 945,
#  'runs': 946,
#  'unbridled': 947,
#  'course': 948,
#  'pacified': 949,
#  'kissed': 950,
#  'dialect': 951,
#  'voice': 952,
#  'adding': 953,
#  'frost': 954,
#  'gets': 955,
#  'bakeshop': 956,
#  'meals': 957,
#  'together': 958,
#  'gigantically': 959,
#  'ramparts': 960,
#  'plumed': 961,
#  'pallid': 962,
#  'receipted': 963,
#  'yard': 964,
#  'today': 965,
#  'thoughts': 966,
#  'started': 967,
#  'courting': 968,
#  'read': 969,
#  'another': 970,
#  'roads': 971,
#  'diverged': 972,
#  'wood': 973,
#  'gentle': 974,
#  'air': 975,
#  'dallied': 976,
#  'minute': 977,
#  'strains': 978,
#  'hard': 979,
#  'fingers': 980,
#  'use': 981,
#  'unless': 982,
#  'lies': 983,
#  'charred': 984,
#  'guess': 985,
#  'theyd': 986,
#  'drag': 987,
#  'again': 988,
#  'weeping': 989,
#  'bless': 990,
#  'serious': 991,
#  'sober': 992,
#  'beyond': 993,
#  'utterance': 994,
#  'human': 995,
#  'tongue': 996,
#  'except': 997,
#  'seemed': 998,
#  'poetesss': 999,
#  ...}

# %%
len(word2idx)
# Out:
# 2527

# %%
# convert data into integer format
train_text_int = []
test_text_int = []

for text in train_text:
  tokens = text.split()
  line_as_int = [word2idx[token] for token in tokens]
  train_text_int.append(line_as_int)

for text in test_text:
  tokens = text.split()
  line_as_int = [word2idx.get(token, 0) for token in tokens]
  test_text_int.append(line_as_int)

# %%
train_text_int[100:105]
# Out:
# [[47, 312, 37, 90, 37, 48, 29, 37, 391],
#  [144, 99, 192, 354, 392, 393, 20, 394],
#  [252, 395, 396, 12, 34, 150, 34, 6, 397],
#  [37, 114, 112, 398, 24, 37, 112, 138, 177],
#  [6, 399, 400, 286, 401, 402]]

# %%
# initialize A and pi matrices - for both classes
V = len(word2idx)

A0 = np.ones((V, V))
pi0 = np.ones(V)

A1 = np.ones((V, V))
pi1 = np.ones(V)

# %%
# compute counts for A and pi
def compute_counts(text_as_int, A, pi):
  for tokens in text_as_int:
    last_idx = None
    for idx in tokens:
      if last_idx is None:
        # it's the first word in a sentence
        pi[idx] += 1
      else:
        # the last word exists, so count a transition
        A[last_idx, idx] += 1

      # update last idx
      last_idx = idx


compute_counts([t for t, y in zip(train_text_int, Ytrain) if y == 0], A0, pi0)
compute_counts([t for t, y in zip(train_text_int, Ytrain) if y == 1], A1, pi1)

# %%
# normalize A and pi so they are valid probability matrices
# convince yourself that this is equivalent to the formulas shown before
A0 /= A0.sum(axis=1, keepdims=True)
pi0 /= pi0.sum()

A1 /= A1.sum(axis=1, keepdims=True)
pi1 /= pi1.sum()

# %%
# log A and pi since we don't need the actual probs
logA0 = np.log(A0)
logpi0 = np.log(pi0)

logA1 = np.log(A1)
logpi1 = np.log(pi1)

# %%
# compute priors
count0 = sum(y == 0 for y in Ytrain)
count1 = sum(y == 1 for y in Ytrain)
total = len(Ytrain)
p0 = count0 / total
p1 = count1 / total
logp0 = np.log(p0)
logp1 = np.log(p1)
p0, p1
# Out:
# (0.3306501547987616, 0.6693498452012384)

# %%
# build a classifier
class Classifier:
  def __init__(self, logAs, logpis, logpriors):
    self.logAs = logAs
    self.logpis = logpis
    self.logpriors = logpriors
    self.K = len(logpriors) # number of classes

  def _compute_log_likelihood(self, input_, class_):
    logA = self.logAs[class_]
    logpi = self.logpis[class_]

    last_idx = None
    logprob = 0
    for idx in input_:
      if last_idx is None:
        # it's the first token
        logprob += logpi[idx]
      else:
        logprob += logA[last_idx, idx]

      # update last_idx
      last_idx = idx

    return logprob

  def predict(self, inputs):
    predictions = np.zeros(len(inputs))
    for i, input_ in enumerate(inputs):
      posteriors = [self._compute_log_likelihood(input_, c) + self.logpriors[c] \
             for c in range(self.K)]
      pred = np.argmax(posteriors)
      predictions[i] = pred
    return predictions

# %%
# each array must be in order since classes are assumed to index these lists
clf = Classifier([logA0, logA1], [logpi0, logpi1], [logp0, logp1])

# %%
Ptrain = clf.predict(train_text_int)
print(f"Train acc: {np.mean(Ptrain == Ytrain)}")
# Out:
# Train acc: 0.9969040247678018

# %%
Ptest = clf.predict(test_text_int)
print(f"Test acc: {np.mean(Ptest == Ytest)}")
# Out:
# Test acc: 0.8163265306122449

# %%
from sklearn.metrics import confusion_matrix, f1_score

# read about F-score: https://en.wikipedia.org/wiki/F-score

# %%
cm = confusion_matrix(Ytrain, Ptrain)
cm
# Out:
# array([[ 529,    5],
#        [   0, 1081]])

# %%
cm_test = confusion_matrix(Ytest, Ptest)
cm_test
# Out:
# array([[ 94,  90],
#        [  9, 346]])

# %%
f1_score(Ytrain, Ptrain)
# Out:
# 0.997692662667282

# %%
f1_score(Ytest, Ptest)
# Out:
# 0.8748419721871049
